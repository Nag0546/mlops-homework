# %%
# Q2: Metric Monitoring for NYC Taxi Data
# ---------------------------------------
# Goal: Add one metric of choice and a quantile value for "fare_amount" column (quantile=0.5)
# We use Evidently (latest version, v0.5+) for data quality monitoring

import pandas as pd
from evidently import Report
from evidently.metrics import QuantileValue, MissingValueCount
import json

# Step 1: Load March 2024 Green Taxi data
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Step 2: Compute trip duration and filter out unrealistic trips
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

# Step 3: Split dataset into reference and current for monitoring
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Step 4: Define metrics to monitor
# - MissingValueCount: tracks number of missing values in 'fare_amount'
# - QuantileValue: tracks median (0.5 quantile) of 'fare_amount'
report = Report(metrics=[
    MissingValueCount(column="fare_amount"),
    QuantileValue(column="fare_amount", quantile=0.5)
])

# Step 5: Run report to compute metrics
report.run(reference_data=reference_data, current_data=current_data)

# Step 6: Extract metrics programmatically
report_json_str = report.render_json()  # returns JSON string
metrics_dict = json.loads(report_json_str)

# Step 7: Get the metrics values
missing_values = metrics_dict["metrics"][0]["result"]["current"]["count"]
median_fare = metrics_dict["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values}")
print(f"Median fare_amount (quantile=0.5): {median_fare}")
# Out:
# /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/core/datasets.py:1146: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/core/datasets.py:1146: RuntimeWarning:
#
# invalid value encountered in scalar divide
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 35
#      32 report.run(reference_data=reference_data, current_data=current_data)
#      34 # Step 6: Extract metrics programmatically
# ---> 35 report_json_str = report.render_json()  # returns JSON string
#      36 metrics_dict = json.loads(report_json_str)
#      38 # Step 7: Get the metrics values
#
# AttributeError: 'Report' object has no attribute 'render_json'

# %%
import pandas as pd
from evidently import Report
from evidently.metrics import QuantileValue, MissingValueCount

# Load March 2024 Green Taxi data
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Compute duration and filter
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

# Split reference & current
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Define metrics
report = Report(metrics=[
    MissingValueCount(column="fare_amount"),
    QuantileValue(column="fare_amount", quantile=0.5)
])

# Run report
report.run(reference_data=reference_data, current_data=current_data)

# Access metrics via report.results
results = report.results  # this is a dictionary

# Extract metric values
missing_values = results["metrics"][0]["result"]["current"]["count"]
median_fare = results["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values}")
print(f"Median fare_amount (quantile=0.5): {median_fare}")
# Out:
# /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/core/datasets.py:1146: RuntimeWarning:
#
# invalid value encountered in scalar divide
#
# /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/core/datasets.py:1146: RuntimeWarning:
#
# invalid value encountered in scalar divide
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 27
#      24 report.run(reference_data=reference_data, current_data=current_data)
#      26 # Access metrics via report.results
# ---> 27 results = report.results  # this is a dictionary
#      29 # Extract metric values
#      30 missing_values = results["metrics"][0]["result"]["current"]["count"]
#
# AttributeError: 'Report' object has no attribute 'results'

# %%
pip install evidently==0.4.35
# Out:
#   Cell In[9], line 1
#     pip install evidently==0.4.35
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install evidently==0.4.35
# Out:
# Collecting evidently==0.4.35
#   Downloading evidently-0.4.35-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: plotly>=5.10.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (5.24.1)
# Requirement already satisfied: statsmodels>=0.12.2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (0.14.6)
# Requirement already satisfied: scikit-learn>=1.0.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (1.3.1)
# Requirement already satisfied: pandas>=1.3.5 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.4.35) (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (1.26.4)
# Requirement already satisfied: nltk>=3.6.7 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (3.9.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (1.15.3)
# Requirement already satisfied: requests>=2.32.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2.32.5)
# Requirement already satisfied: PyYAML>=5.4 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (6.0.3)
# Requirement already satisfied: pydantic>=1.10.13 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2.12.5)
# Requirement already satisfied: litestar>=2.8.3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2.19.0)
# Requirement already satisfied: typing-inspect>=0.9.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (0.9.0)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (0.38.0)
# Requirement already satisfied: watchdog>=3.0.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (6.0.0)
# Requirement already satisfied: typer>=0.3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (0.20.0)
# Requirement already satisfied: rich>=13 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (14.2.0)
# Requirement already satisfied: iterative-telemetry>=0.0.5 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (0.0.10)
# Requirement already satisfied: dynaconf>=3.2.4 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (3.2.12)
# Requirement already satisfied: certifi>=2024.7.4 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2025.11.12)
# Requirement already satisfied: urllib3>=1.26.19 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2.6.2)
# Requirement already satisfied: fsspec>=2024.2.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2025.12.0)
# Requirement already satisfied: ujson>=5.4.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (5.11.0)
# Requirement already satisfied: deprecation>=2.1.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (2.1.0)
# Collecting opentelemetry-api>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: opentelemetry-proto>=1.25.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from evidently==0.4.35) (1.39.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.25.0 (from evidently==0.4.35)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.25.0 (from evidently==0.4.35)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from deprecation>=2.1.0->evidently==0.4.35) (25.0)
# Requirement already satisfied: appdirs in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.4.35) (1.4.4)
# Requirement already satisfied: filelock in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.4.35) (3.20.1)
# Requirement already satisfied: distro in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from iterative-telemetry>=0.0.5->evidently==0.4.35) (1.9.0)
# Requirement already satisfied: anyio>=3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (4.12.0)
# Requirement already satisfied: click in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (8.3.1)
# Requirement already satisfied: exceptiongroup in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (1.3.1)
# Requirement already satisfied: httpx>=0.22 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (0.28.1)
# Requirement already satisfied: litestar-htmx>=0.4.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (0.5.0)
# Requirement already satisfied: msgspec>=0.18.2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (0.20.0)
# Requirement already satisfied: multidict>=6.0.2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (6.7.0)
# Requirement already satisfied: multipart>=1.2.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (1.3.0)
# Requirement already satisfied: polyfactory>=2.6.3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (3.1.0)
# Requirement already satisfied: rich-click in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (1.9.4)
# Requirement already satisfied: sniffio>=1.3.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (1.3.1)
# Requirement already satisfied: typing-extensions in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.4.35) (3.11)
# Requirement already satisfied: httpcore==1.* in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.4.35) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.8.3->evidently==0.4.35) (0.16.0)
# Requirement already satisfied: joblib in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.4.35) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.4.35) (2025.11.3)
# Requirement already satisfied: tqdm in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.4.35) (4.67.1)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.25.0->evidently==0.4.35)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.25.0->evidently==0.4.35)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting grpcio<2.0.0,>=1.63.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Downloading grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from opentelemetry-proto>=1.25.0->evidently==0.4.35) (6.33.2)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk>=1.25.0->evidently==0.4.35)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.4.35) (3.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2025.3)
# Requirement already satisfied: pyarrow>=10.0.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.4.35) (22.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from plotly>=5.10.0->evidently==0.4.35) (9.1.2)
# Requirement already satisfied: faker>=5.0.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.4.35) (38.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.4.35) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.4.35) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from pydantic>=1.10.13->evidently==0.4.35) (0.4.2)
# Requirement already satisfied: six>=1.5 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from rich>=13->evidently==0.4.35) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from rich>=13->evidently==0.4.35) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13->evidently==0.4.35) (0.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from scikit-learn>=1.0.1->evidently==0.4.35) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from statsmodels>=0.12.2->evidently==0.4.35) (1.0.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from typer>=0.3->evidently==0.4.35) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from typing-inspect>=0.9.0->evidently==0.4.35) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages (from uvicorn[standard]>=0.22.0->evidently==0.4.35) (15.0.1)
# Downloading evidently-0.4.35-py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.4 MB/s  0:00:02m 3.2 MB/s eta 0:00:01
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Downloading grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 17.1 MB/s  0:00:007.3 MB/s eta 0:00:0101
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Downloading opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl (19 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, grpcio, googleapis-common-protos, opentelemetry-exporter-otlp-proto-common, importlib-metadata, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, evidently
#   Attempting uninstall: evidently━━━━━━╺━━━━━━━━━━━━━━━━━━━━━  5/11 [opentelemetry-api]
#     Found existing installation: evidently 0.7.17m╺━━━━━━━━━━━━━━━━━━━━━  5/11 [opentelemetry-api]
#     Uninstalling evidently-0.7.17:━━━━━━━━━━━━━━━━━━━━━━━╺━━━ 10/11 [evidently]api]
#       Successfully uninstalled evidently-0.7.17━━━━━━╺━━━ 10/11 [evidently]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [evidently] 10/11 [evidently]
# Successfully installed evidently-0.4.35 googleapis-common-protos-1.72.0 grpcio-1.76.0 importlib-metadata-8.7.0 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-exporter-otlp-proto-http-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 zipp-3.23.0

# %%
# Step 0: Make sure you have Evidently v0.4.35 installed
# pip install evidently==0.4.35

import pandas as pd
from evidently.report import Report
from evidently.metrics import ColumnQuantileMetric, DatasetMissingValuesMetric

# Step 1: Load March 2024 Green Taxi data
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Step 2: Compute duration and filter unrealistic trips
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

# Step 3: Split into reference and current datasets
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Step 4: Define metrics
# - DatasetMissingValuesMetric: counts missing values in fare_amount
# - ColumnQuantileMetric: computes quantile (median) of fare_amount
report = Report(metrics=[
    DatasetMissingValuesMetric(column_name="fare_amount"),
    ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)
])

# Step 5: Run the report
report.run(reference_data=reference_data, current_data=current_data)

# Step 6: Extract metrics programmatically
results = report.as_dict()  # This works in Evidently v0.4.35

missing_values = results["metrics"][0]["result"]["current"]["count"]
median_fare = results["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values}")
print(f"Median fare_amount (quantile=0.5): {median_fare}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 5
#       1 # Step 0: Make sure you have Evidently v0.4.35 installed
#       2 # pip install evidently==0.4.35
#       4 import pandas as pd
# ----> 5 from evidently.report import Report
#       6 from evidently.metrics import ColumnQuantileMetric, DatasetMissingValuesMetric
#       8 # Step 1: Load March 2024 Green Taxi data
#
# File ~/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/report/__init__.py:1
# ----> 1 from .report import Report
#       3 __all__ = ["Report"]
#
# File ~/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/report/report.py:15
#      11 from typing import Union
#      13 import pandas as pd
# ---> 15 from evidently.base_metric import GenericInputData
#      16 from evidently.base_metric import Metric
#      17 from evidently.calculation_engine.engine import Engine
#
# File ~/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/base_metric.py:23
#      21 from evidently._pydantic_compat import ModelMetaclass
#      22 from evidently._pydantic_compat import PrivateAttr
# ---> 23 from evidently.core import BaseResult
#      24 from evidently.core import ColumnType
#      25 from evidently.core import IncludeTags
#
# ImportError: cannot import name 'BaseResult' from 'evidently.core' (/Users/nageswara_regula/Desktop/mlops-homework/04-deployment/homework/nbfix-env/lib/python3.10/site-packages/evidently/core/__init__.py)

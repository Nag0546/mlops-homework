# %%
# Step 0: Install packages if needed
# In terminal:
# pip install pandas numpy scikit-learn xgboost evidently==0.4.35

# Step 1: Imports
import pandas as pd
from evidently.report import Report
from evidently.metrics import ColumnQuantileMetric, DatasetMissingValuesMetric

# -----------------------
# Q1: Prepare the dataset
# -----------------------

# Load March 2024 Green Taxi data
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Compute trip duration and filter out unrealistic trips
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

# Show dataset shape
print(f"Dataset shape after filtering: {df.shape}")
print(f"Number of rows: {df.shape[0]}")

# -----------------------
# Q2: Metrics
# -----------------------

# Split data into reference and current datasets
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Define Evidently metrics
report = Report(metrics=[
    DatasetMissingValuesMetric(column_name="fare_amount"),  # missing values metric
    ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)  # median fare
])

# Run the report
report.run(reference_data=reference_data, current_data=current_data)

# Extract results programmatically
results = report.as_dict()

missing_values = results["metrics"][0]["result"]["current"]["count"]
median_fare = results["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values}")
print(f"Median fare_amount (quantile=0.5): {median_fare}")
# Out:
# Dataset shape after filtering: (55139, 21)
# Number of rows: 55139
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 36
#      32 current_data = df.drop(reference_data.index)
#      34 # Define Evidently metrics
#      35 report = Report(metrics=[
# ---> 36     DatasetMissingValuesMetric(column_name="fare_amount"),  # missing values metric
#      37     ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)  # median fare
#      38 ])
#      40 # Run the report
#      41 report.run(reference_data=reference_data, current_data=current_data)
#
# TypeError: DatasetMissingValuesMetric.__init__() got an unexpected keyword argument 'column_name'

# %%
pip install evidently==0.4.35
# Out:
# Collecting evidently==0.4.35
#   Using cached evidently-0.4.35-py3-none-any.whl.metadata (11 kB)
# Collecting plotly>=5.10.0 (from evidently==0.4.35)
#   Using cached plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting statsmodels>=0.12.2 (from evidently==0.4.35)
#   Using cached statsmodels-0.14.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: scikit-learn>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (1.7.2)
# Requirement already satisfied: pandas>=1.3.5 in /opt/homebrew/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.4.35) (2.3.3)
# Requirement already satisfied: numpy>=1.22.0 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (2.2.6)
# Collecting nltk>=3.6.7 (from evidently==0.4.35)
#   Using cached nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy>=1.10.0 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (1.15.3)
# Requirement already satisfied: requests>=2.32.0 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (2.32.5)
# Requirement already satisfied: PyYAML>=5.4 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (6.0.3)
# Collecting pydantic>=1.10.13 (from evidently==0.4.35)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting litestar>=2.8.3 (from evidently==0.4.35)
#   Using cached litestar-2.19.0-py3-none-any.whl.metadata (26 kB)
# Collecting typing-inspect>=0.9.0 (from evidently==0.4.35)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting uvicorn>=0.22.0 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting watchdog>=3.0.0 (from evidently==0.4.35)
#   Using cached watchdog-6.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (44 kB)
# Collecting typer>=0.3 (from evidently==0.4.35)
#   Using cached typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting rich>=13 (from evidently==0.4.35)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting iterative-telemetry>=0.0.5 (from evidently==0.4.35)
#   Using cached iterative_telemetry-0.0.10-py3-none-any.whl.metadata (4.1 kB)
# Collecting dynaconf>=3.2.4 (from evidently==0.4.35)
#   Using cached dynaconf-3.2.12-py2.py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (2025.11.12)
# Requirement already satisfied: urllib3>=1.26.19 in /opt/homebrew/lib/python3.10/site-packages (from evidently==0.4.35) (2.6.2)
# Collecting fsspec>=2024.2.0 (from evidently==0.4.35)
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting ujson>=5.4.0 (from evidently==0.4.35)
#   Using cached ujson-5.11.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.4 kB)
# Collecting deprecation>=2.1.0 (from evidently==0.4.35)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting opentelemetry-api>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-proto>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_proto-1.39.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.25.0 (from evidently==0.4.35)
#   Using cached opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.10/site-packages (from deprecation>=2.1.0->evidently==0.4.35) (25.0)
# Collecting appdirs (from iterative-telemetry>=0.0.5->evidently==0.4.35)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting filelock (from iterative-telemetry>=0.0.5->evidently==0.4.35)
#   Using cached filelock-3.20.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting distro (from iterative-telemetry>=0.0.5->evidently==0.4.35)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio>=3 in /opt/homebrew/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (4.12.0)
# Collecting click (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: exceptiongroup in /opt/homebrew/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (1.3.1)
# Requirement already satisfied: httpx>=0.22 in /opt/homebrew/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (0.28.1)
# Collecting litestar-htmx>=0.4.0 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached litestar_htmx-0.5.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting msgspec>=0.18.2 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached msgspec-0.20.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting multidict>=6.0.2 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached multidict-6.7.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting multipart>=1.2.0 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached multipart-1.3.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting polyfactory>=2.6.3 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached polyfactory-3.1.0-py3-none-any.whl.metadata (27 kB)
# Collecting rich-click (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached rich_click-1.9.4-py3-none-any.whl.metadata (8.7 kB)
# Collecting sniffio>=1.3.1 (from litestar>=2.8.3->evidently==0.4.35)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions in /opt/homebrew/lib/python3.10/site-packages (from litestar>=2.8.3->evidently==0.4.35) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.10/site-packages (from anyio>=3->litestar>=2.8.3->evidently==0.4.35) (3.11)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.10/site-packages (from httpx>=0.22->litestar>=2.8.3->evidently==0.4.35) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/homebrew/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.22->litestar>=2.8.3->evidently==0.4.35) (0.16.0)
# Requirement already satisfied: joblib in /opt/homebrew/lib/python3.10/site-packages (from nltk>=3.6.7->evidently==0.4.35) (1.5.3)
# Collecting regex>=2021.8.3 (from nltk>=3.6.7->evidently==0.4.35)
#   Using cached regex-2025.11.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tqdm (from nltk>=3.6.7->evidently==0.4.35)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.25.0->evidently==0.4.35)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.25.0->evidently==0.4.35)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Using cached googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting grpcio<2.0.0,>=1.63.2 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Using cached grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.39.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.25.0->evidently==0.4.35)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting protobuf<7.0,>=5.0 (from opentelemetry-proto>=1.25.0->evidently==0.4.35)
#   Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting opentelemetry-semantic-conventions==0.60b1 (from opentelemetry-sdk>=1.25.0->evidently==0.4.35)
#   Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.32.0->evidently==0.4.35) (3.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.10/site-packages (from pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (2025.3)
# Requirement already satisfied: pyarrow>=10.0.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas[parquet]>=1.3.5->evidently==0.4.35) (22.0.0)
# Collecting narwhals>=1.15.1 (from plotly>=5.10.0->evidently==0.4.35)
#   Using cached narwhals-2.14.0-py3-none-any.whl.metadata (13 kB)
# Collecting faker>=5.0.0 (from polyfactory>=2.6.3->litestar>=2.8.3->evidently==0.4.35)
#   Using cached faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=1.10.13->evidently==0.4.35)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=1.10.13->evidently==0.4.35)
#   Using cached pydantic_core-2.41.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=1.10.13->evidently==0.4.35)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.5->pandas[parquet]>=1.3.5->evidently==0.4.35) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=13->evidently==0.4.35)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=13->evidently==0.4.35) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13->evidently==0.4.35)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn>=1.0.1->evidently==0.4.35) (3.6.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.12.2->evidently==0.4.35)
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting shellingham>=1.3.0 (from typer>=0.3->evidently==0.4.35)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.9.0->evidently==0.4.35)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached httptools-0.7.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached uvloop-0.22.1-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached watchfiles-1.1.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.22.0->evidently==0.4.35)
#   Using cached websockets-15.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Using cached evidently-0.4.35-py3-none-any.whl (3.4 MB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Using cached dynaconf-3.2.12-py2.py3-none-any.whl (237 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Using cached iterative_telemetry-0.0.10-py3-none-any.whl (10 kB)
# Using cached litestar-2.19.0-py3-none-any.whl (565 kB)
# Using cached litestar_htmx-0.5.0-py3-none-any.whl (10.0 kB)
# Using cached msgspec-0.20.0-cp310-cp310-macosx_11_0_arm64.whl (188 kB)
# Using cached multidict-6.7.0-cp310-cp310-macosx_11_0_arm64.whl (44 kB)
# Using cached multipart-1.3.0-py3-none-any.whl (14 kB)
# Using cached nltk-3.9.2-py3-none-any.whl (1.5 MB)
# Using cached opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.39.1-py3-none-any.whl (19 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.39.1-py3-none-any.whl (18 kB)
# Using cached opentelemetry_proto-1.39.1-py3-none-any.whl (72 kB)
# Using cached googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
# Using cached grpcio-1.76.0-cp310-cp310-macosx_11_0_universal2.whl (11.8 MB)
# Using cached opentelemetry_sdk-1.39.1-py3-none-any.whl (132 kB)
# Using cached opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
# Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached opentelemetry_exporter_otlp_proto_http-1.39.1-py3-none-any.whl (19 kB)
# Using cached plotly-6.5.0-py3-none-any.whl (9.9 MB)
# Using cached narwhals-2.14.0-py3-none-any.whl (430 kB)
# Using cached polyfactory-3.1.0-py3-none-any.whl (61 kB)
# Using cached faker-38.2.0-py3-none-any.whl (2.0 MB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached regex-2025.11.3-cp310-cp310-macosx_11_0_arm64.whl (288 kB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached statsmodels-0.14.6-cp310-cp310-macosx_11_0_arm64.whl (10.0 MB)
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Using cached typer-0.20.0-py3-none-any.whl (47 kB)
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached ujson-5.11.0-cp310-cp310-macosx_11_0_arm64.whl (53 kB)
# Using cached uvicorn-0.38.0-py3-none-any.whl (68 kB)
# Using cached httptools-0.7.1-cp310-cp310-macosx_11_0_arm64.whl (109 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached uvloop-0.22.1-cp310-cp310-macosx_10_9_universal2.whl (1.3 MB)
# Using cached watchdog-6.0.0-cp310-cp310-macosx_11_0_arm64.whl (89 kB)
# Using cached watchfiles-1.1.1-cp310-cp310-macosx_11_0_arm64.whl (394 kB)
# Using cached websockets-15.0.1-cp310-cp310-macosx_11_0_arm64.whl (173 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached filelock-3.20.1-py3-none-any.whl (16 kB)
# Using cached rich_click-1.9.4-py3-none-any.whl (70 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: appdirs, zipp, websockets, watchdog, uvloop, ujson, typing-inspection, tqdm, sniffio, shellingham, regex, python-dotenv, pydantic-core, protobuf, patsy, narwhals, mypy-extensions, multipart, multidict, msgspec, mdurl, litestar-htmx, httptools, grpcio, fsspec, filelock, faker, dynaconf, distro, deprecation, click, annotated-types, uvicorn, typing-inspect, pydantic, polyfactory, plotly, opentelemetry-proto, nltk, markdown-it-py, iterative-telemetry, importlib-metadata, googleapis-common-protos, watchfiles, statsmodels, rich, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, typer, rich-click, opentelemetry-semantic-conventions, opentelemetry-sdk, litestar, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, evidently
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56/56 [evidently] [evidently] [opentelemetry-exporter-otlp-proto-grpc]
# Successfully installed annotated-types-0.7.0 appdirs-1.4.4 click-8.3.1 deprecation-2.1.0 distro-1.9.0 dynaconf-3.2.12 evidently-0.4.35 faker-38.2.0 filelock-3.20.1 fsspec-2025.12.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 httptools-0.7.1 importlib-metadata-8.7.0 iterative-telemetry-0.0.10 litestar-2.19.0 litestar-htmx-0.5.0 markdown-it-py-4.0.0 mdurl-0.1.2 msgspec-0.20.0 multidict-6.7.0 multipart-1.3.0 mypy-extensions-1.1.0 narwhals-2.14.0 nltk-3.9.2 opentelemetry-api-1.39.1 opentelemetry-exporter-otlp-proto-common-1.39.1 opentelemetry-exporter-otlp-proto-grpc-1.39.1 opentelemetry-exporter-otlp-proto-http-1.39.1 opentelemetry-proto-1.39.1 opentelemetry-sdk-1.39.1 opentelemetry-semantic-conventions-0.60b1 patsy-1.0.2 plotly-6.5.0 polyfactory-3.1.0 protobuf-6.33.2 pydantic-2.12.5 pydantic-core-2.41.5 python-dotenv-1.2.1 regex-2025.11.3 rich-14.2.0 rich-click-1.9.4 shellingham-1.5.4 sniffio-1.3.1 statsmodels-0.14.6 tqdm-4.67.1 typer-0.20.0 typing-inspect-0.9.0 typing-inspection-0.4.2 ujson-5.11.0 uvicorn-0.38.0 uvloop-0.22.1 watchdog-6.0.0 watchfiles-1.1.1 websockets-15.0.1 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
python -c "import evidently; print(evidently.__version__)"
# Out:
#   Cell In[3], line 1
#     python -c "import evidently; print(evidently.__version__)"
#               ^
# SyntaxError: invalid syntax

# %%
# =====================================================
# Q1 + Q2: NYC Taxi Data Preparation and Metrics
# =====================================================

# Step 0: Imports
import pandas as pd
from evidently.report import Report
from evidently.metrics import ColumnQuantileMetric, DatasetMissingValuesMetric

# -----------------------
# Q1: Prepare the dataset
# -----------------------

# Load March 2024 Green Taxi data
url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Compute trip duration and filter unrealistic trips
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

print(f"Dataset shape after filtering: {df.shape}")
print(f"Number of rows: {df.shape[0]}")

# -----------------------
# Q2: Metrics
# -----------------------

# Split dataset into reference and current
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Define Evidently metrics
metrics = [
    DatasetMissingValuesMetric(),  # track missing values for all columns
    ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)  # median fare
]

report = Report(metrics=metrics)

# Run the report
report.run(reference_data=reference_data, current_data=current_data)

# -----------------------
# Extract metrics programmatically
# -----------------------

results = report.as_dict()

# Step 1: DatasetMissingValuesMetric
missing_values_result = results["metrics"][0]["result"]["current"]
# Extract missing values for 'fare_amount'
missing_values_fare_amount = missing_values_result.get("fare_amount", None)

# Step 2: ColumnQuantileMetric
median_fare = results["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values_fare_amount}")
print(f"Median fare_amount (0.5 quantile): {median_fare}")

# =====================================================
# ✅ Done! This notebook covers:
# - Q1: dataset shape and filtering
# - Q2: metrics monitoring (missing values + median fare)
# =====================================================
# Out:
# Dataset shape after filtering: (55139, 21)
# Number of rows: 55139
# Missing values in fare_amount: None
# Median fare_amount (0.5 quantile): 13.5

# %%
# Step 1: Imports for Evidently metrics
from evidently.report import Report
from evidently.metrics import ColumnQuantileMetric, DatasetMissingValuesMetric

# Split dataset into reference and current
reference_data = df.sample(frac=0.5, random_state=42)
current_data = df.drop(reference_data.index)

# Define Evidently metrics
metrics = [
    DatasetMissingValuesMetric(),  # track missing values for all columns
    ColumnQuantileMetric(column_name="fare_amount", quantile=0.5)  # median fare
]

# Create and run the report
report = Report(metrics=metrics)
report.run(reference_data=reference_data, current_data=current_data)

# Extract metrics programmatically
results = report.as_dict()

# Missing values for 'fare_amount'
missing_values_result = results["metrics"][0]["result"]["current"]
missing_values_fare_amount = missing_values_result.get("fare_amount", None)

# Median fare (0.5 quantile)
median_fare = results["metrics"][1]["result"]["current"]["value"]

print(f"Missing values in fare_amount: {missing_values_fare_amount}")
print(f"Median fare_amount (0.5 quantile): {median_fare}")
# Out:
# Missing values in fare_amount: None
# Median fare_amount (0.5 quantile): 13.5

# %%
import pandas as pd

url = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-03.parquet"
df = pd.read_parquet(url)

# Compute trip duration and filter unrealistic trips
df["duration"] = (df.lpep_dropoff_datetime - df.lpep_pickup_datetime).dt.total_seconds() / 60
df = df[(df.duration >= 1) & (df.duration <= 60)]

# Convert pickup datetime to date for daily aggregation
df['pickup_date'] = df.lpep_pickup_datetime.dt.date

# %%
daily_median_fare = df.groupby('pickup_date')['fare_amount'].quantile(0.5)
print(daily_median_fare)
# Out:
# pickup_date
# 2024-02-23    20.000
# 2024-02-25    12.100
# 2024-02-29    34.000
# 2024-03-01    13.500
# 2024-03-02    13.500
# 2024-03-03    14.200
# 2024-03-04    12.800
# 2024-03-05    13.500
# 2024-03-06    12.800
# 2024-03-07    13.500
# 2024-03-08    13.185
# 2024-03-09    13.500
# 2024-03-10    14.200
# 2024-03-11    12.800
# 2024-03-12    13.500
# 2024-03-13    13.500
# 2024-03-14    14.200
# 2024-03-15    13.500
# 2024-03-16    13.500
# 2024-03-17    13.500
# 2024-03-18    13.500
# 2024-03-19    13.500
# 2024-03-20    13.430
# 2024-03-21    13.500
# 2024-03-22    13.500
# 2024-03-23    12.800
# 2024-03-24    14.200
# 2024-03-25    13.500
# 2024-03-26    13.500
# 2024-03-27    13.500
# 2024-03-28    13.500
# 2024-03-29    13.460
# 2024-03-30    14.200
# 2024-03-31    13.500
# 2024-04-01     5.800
# Name: fare_amount, dtype: float64

# %%
max_daily_median = daily_median_fare.max()
print(f"Maximum daily median fare (quantile=0.5): {max_daily_median}")
# Out:
# Maximum daily median fare (quantile=0.5): 34.0
